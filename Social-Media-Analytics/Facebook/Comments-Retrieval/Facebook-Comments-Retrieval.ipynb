# %%
from __future__ import absolute_import
from google.cloud import language
import google.cloud
import pandas as pd
import numpy as np
import tqdm
import operator
import facebook
import json
import tweepy
import time
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import datetime
import dateutil.parser as dateparser


#Create client instance for Google Natural Language API
client = language.Client()

# %%
# Facebook Credentials

FB_APP_ID = 'FB_APP_ID'
FB_APP_SECRET = 'FB_APP_SECRET'

USER_ID = 'USER_ID'

USER_TOKEN= 'USER_TOKEN'
FB_TOKEN = 'FB_TOKEN'

# Facebook Graph API
graph = facebook.GraphAPI(access_token=FB_TOKEN, version='2.2')

#graph.extend_access_token(FB_APP_ID, FB_APP_SECRET)

# %%
since = '2017-02-26'
until = '2017-03-07'

# %%
fb_comments_df = pd.DataFrame(columns = ['reply_comment_date', 'reply_comment_time', 'reply_comment_text', \
                                          'reply_comment_id', 'reply_username', 'reply_user_id', 'brand', 'post_date',\
                                          'post_time', 'post_text', 'post_id'])

# %%
brand_id = '123456789'
brand = 'RDU'

temp_post_objects = graph.get_connections(brand_id, 'posts', since = since, until = until)
temp_posts = {}
while(True):
    try:
        for temp_post_object in temp_post_objects['data']:
            temp_posts[(temp_post_object['id'], dateparser.parse(temp_post_object['created_time']))] = temp_post_object['message'] 
        temp_post_objects = requests.get(temp_post_object['paging']['next']).json()
    except KeyError:
        break

temp_fb_comments_df = pd.DataFrame(columns = ['reply_comment_date', 'reply_comment_time', 'reply_comment_text', \
                                      'reply_comment_id', 'reply_username', 'reply_user_id', 'brand', 'post_date',\
                                      'post_time', 'post_text', 'post_id'])

for post_meta in temp_posts:

    # Get datetime of the UF post
    post_datetime = post_meta[1]
    post_date = str(post_datetime.date())
    post_time = str(post_datetime.time())
    post_text = temp_posts[post_meta]
    post_id = post_meta[0]

    reply_comment_date_list = []
    reply_comment_time_list = []
    reply_comment_text_list = []
    reply_comment_id_list = []
    reply_user_name_list = []
    reply_user_id_list = []

    #user_commenter_ageRange_list = []
    #user_commenter_education_list = []
    #user_commenter_gender_list = []
    #user_commenter_location_list = []

    # Start initial comments object for iteration; all comments under post, including pagination info
    comments = graph.get_connections(post_id, 'comments')
    while(True):
        try:
            for comment in comments['data']:
                reply_comment_date_list.append(str(dateparser.parse(comment['created_time']).date()))
                reply_comment_time_list.append(dateparser.parse(str(dateparser.parse(comment['created_time']).time())))
                reply_comment_text_list.append(comment['message'])
                reply_comment_id_list.append(comment['id'])
                reply_user_name_list.append(comment['from']['name'])
                reply_user_id_list.append(comment['from']['id'])

                # Get commenter's location
                #user_commenter_id = comment['from']['id']
                #user_commenter_profile = graph.get_object(user_commenter_id)

            commments = requests.get(comment['paging']['next']).json()
        except KeyError:
            break

    temp_df = pd.DataFrame(columns = ['reply_comment_date', 'reply_comment_time', 'reply_comment_text', \
                                      'reply_comment_id', 'reply_username', 'reply_user_id', 'brand', 'post_date',\
                                      'post_time', 'post_text', 'post_id'])

    temp_df['reply_comment_date'] = reply_comment_date_list
    temp_df['reply_comment_time'] = reply_comment_time_list
    temp_df['reply_comment_text'] = reply_comment_text_list
    temp_df['reply_comment_id'] = reply_comment_id_list
    temp_df['reply_username'] = reply_user_name_list
    temp_df['reply_user_id'] = reply_user_id_list
    temp_df['brand'] = brand
    temp_df['post_date'] = post_date
    temp_df['post_time'] = post_time
    temp_df['post_text'] = post_text
    temp_df['post_id'] = post_id

    temp_fb_comments_df = pd.concat([temp_fb_comments_df, temp_df])

fb_comments_df = pd.concat([fb_comments_df, temp_fb_comments_df])

# %%
fb_comments_df
# Out:
#    reply_comment_date  reply_comment_time  \
# 0          2017-03-07 2017-03-07 00:23:13
# 1          2017-03-06 2017-03-07 02:25:36
# 2          2017-03-06 2017-03-07 00:17:00
# 3          2017-03-06 2017-03-07 12:22:12
# 4          2017-03-06 2017-03-07 01:12:45
# 5          2017-03-05 2017-03-07 23:45:31
# 6          2017-03-05 2017-03-07 22:57:18
# 7          2017-03-06 2017-03-07 02:57:12
# 8          2017-03-06 2017-03-07 00:58:49
# 9          2017-03-06 2017-03-07 00:41:52
# 10         2017-03-06 2017-03-07 20:46:06
# 11         2017-03-05 2017-03-07 23:52:17
# 12         2017-03-06 2017-03-07 02:05:25
# 13         2017-03-06 2017-03-07 15:11:22
# 14         2017-03-06 2017-03-07 19:05:40
# 15         2017-03-06 2017-03-07 12:47:52
# 16         2017-03-05 2017-03-07 23:26:18
# 17         2017-03-06 2017-03-07 12:04:58
# 18         2017-03-05 2017-03-07 23:52:53
# 19         2017-03-06 2017-03-07 01:17:40
# 20         2017-03-07 2017-03-07 02:20:07
# 21         2017-03-07 2017-03-07 00:50:56
# 22         2017-03-06 2017-03-07 16:28:20
# 23         2017-03-06 2017-03-07 17:28:37
# 24         2017-03-06 2017-03-07 00:25:12
# 0          2017-03-03 2017-03-07 18:53:36
#
#                                    reply_comment_text  \
# 0   Yeah! The 777 is back.... thank goodness !!!! ...
# 1   Hey Raleigh-Durham International Airport (RDU)...
# 2                              Congratulations RDU!!!
# 3   Almost anything would be better than the one t...
# 4   I have already bought our tickets for non stop...
# 5   Finally! I've been avoiding the RDU-LHR flight...
# 6   Now all we need is Virgin Atlantic RDU to LHR ...
# 7   Thank you America air lines delta air line fro...
# 8   I heard AA was going to fly an MD-80 on this r...
# 9   Don't expect the 777 to last with loads as hor...
# 10  It won't be docking at C-16 like it used to. I...
# 11    Great news travel on this at least twice a year
# 12                                There's my bird! :D
# 13                                       Love this ✈️
# 14  Leslie Felton Allman and Stacey Tracy... the Q...
# 15    Fantastic news, I have a trip coming up soon 😃
# 16              Will be on this plane in July. Thanks
# 17                May we will be on this one in april
# 18                  Exciting. I have an upcoming trip
# 19                              Great news RDU 🎉🎉🎉
# 20                      Thank goodness! I'm so ready.
# 21                                        Yay✈️✈️✈️✈️
# 22  Marissa Williams 🙌🏼 FINALLY seat back entert...
# 23                                                 😊
# 24                                                 😊
# 0                How does one get such a awesome Gig!
#
#                      reply_comment_id  \
# 0   1581432665220060_1582700998426560
# 1   1581432665220060_1581593685203958
# 2   1581432665220060_1581509498545710
# 3   1581432665220060_1581990128497647
# 4   1581432665220060_1581545908542069
# 5   1581432665220060_1581489528547707
# 6   1581432665220060_1581451508551509
# 7   1581432665220060_1581612748535385
# 8   1581432665220060_1581537178542942
# 9   1581432665220060_1581527755210551
# 10  1581432665220060_1582518071778186
# 11  1581432665220060_1581493868547273
# 12  1581432665220060_1581578165205510
# 13  1581432665220060_1582146615148665
# 14  1581432665220060_1582419591788034
# 15  1581432665220060_1582010378495622
# 16  1581432665220060_1581474705215856
# 17  1581432665220060_1581958498500810
# 18  1581432665220060_1581494178547242
# 19  1581432665220060_1581548648541795
# 20  1581432665220060_1582817835081543
# 21  1581432665220060_1582720971757896
# 22  1581432665220060_1582262418470418
# 23  1581432665220060_1582336628462997
# 24  1581432665220060_1581517355211591
# 0   1578001845563142_1578783778818282
#
#                                       reply_username      reply_user_id brand  \
# 0                                     Jill Palombaro   1107902295988536   RDU
# 1                                 Christopher Pippen  10155057211954547   RDU
# 2   Charlotte/Douglas International Airport Overlook    120221124739914   RDU
# 3                                      Emily Wilkins  10212033720176180   RDU
# 4                                      Burak Eryigit  10155055452526505   RDU
# 5                                        Rich Murray  10155217395928755   RDU
# 6                                      Caron Beesley  10155389322039341   RDU
# 7                                         Farid Muti  10211646672699909   RDU
# 8                                     Robert O Smith  10210899061464140   RDU
# 9                                       Chris Murray  10104808865392122   RDU
# 10                                      Kevin Dunham  10154324770736570   RDU
# 11                                    Maxine Gardner  10211245997239937   RDU
# 12                                     Savannah Ford  10208798428741434   RDU
# 13                          Barbie Matukaitis Cromer  10212512127146367   RDU
# 14                                       Josh Allman  10212888224949229   RDU
# 15                                      Angie Crosby  10154427412023634   RDU
# 16                            Linda Kirchner Griffin  10211156576982426   RDU
# 17                            Carolyn Traylor Styron    850189618457249   RDU
# 18                                        Sam Griggs   1686199041395696   RDU
# 19                                     Naomi Osborne  10208919750567373   RDU
# 20                                       Danette Tew    184671345358975   RDU
# 21                                      Lisa Brannon    502140716840083   RDU
# 22                                   Rebecca O'Neill  10104117285209349   RDU
# 23                                   Ellen Armstrong  10208085918857942   RDU
# 24                                        Gavin Reid  10154470882912684   RDU
# 0                                       Thomas Biggs   1441123949251890   RDU
#
#      post_date post_time                                          post_text  \
# 0   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 1   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 2   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 3   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 4   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 5   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 6   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 7   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 8   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 9   2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 10  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 11  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 12  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 13  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 14  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 15  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 16  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 17  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 18  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 19  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 20  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 21  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 22  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 23  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 24  2017-03-05  22:33:42  The @americanair B-777 is now year round to #L...
# 0   2017-03-03  02:50:42  Livin' on the edge... of the runway that is. T...
#
#                              post_id
# 0   145265145503493_1581432665220060
# 1   145265145503493_1581432665220060
# 2   145265145503493_1581432665220060
# 3   145265145503493_1581432665220060
# 4   145265145503493_1581432665220060
# 5   145265145503493_1581432665220060
# 6   145265145503493_1581432665220060
# 7   145265145503493_1581432665220060
# 8   145265145503493_1581432665220060
# 9   145265145503493_1581432665220060
# 10  145265145503493_1581432665220060
# 11  145265145503493_1581432665220060
# 12  145265145503493_1581432665220060
# 13  145265145503493_1581432665220060
# 14  145265145503493_1581432665220060
# 15  145265145503493_1581432665220060
# 16  145265145503493_1581432665220060
# 17  145265145503493_1581432665220060
# 18  145265145503493_1581432665220060
# 19  145265145503493_1581432665220060
# 20  145265145503493_1581432665220060
# 21  145265145503493_1581432665220060
# 22  145265145503493_1581432665220060
# 23  145265145503493_1581432665220060
# 24  145265145503493_1581432665220060
# 0   145265145503493_1578001845563142

# %%
fb_comments_df.to_csv('/Users/thays/Desktop/RDU_pitch/RDUpitch_all_fb_comments.csv', encoding='utf-8')
